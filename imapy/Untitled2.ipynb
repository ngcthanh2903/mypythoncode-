# %%
import cv2
import numpy as np

img = cv2.imread('Best_Black_and_White_Portrait_013.jpg')

res = cv2.resize(img,None,fx=2, fy=2, interpolation = cv2.INTER_CUBIC)



height, width = img.shape[:2]
res = cv2.resize(img,(2*width, 2*height), interpolation = cv2.INTER_CUBIC)

# %%
import cv2
import numpy as np

img = cv2.imread('Best_Black_and_White_Portrait_013.jpg',0)
rows,cols = img.shape

M = np.float32([[1,0,100],[0,1,50]])
dst = cv2.warpAffine(img,M,(cols,rows))

cv2.imshow('img',dst)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = cv2.imread('Best_Black_and_White_Portrait_013.jpg',0)
rows,cols = img.shape

M = cv2.getRotationMatrix2D((cols/2,rows/2),90,1)
dst = cv2.warpAffine(img,M,(cols,rows))

# %%
cv2.imshow('img',dst)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import matplotlib.pyplot as plt 
img = cv2.imread('Best_Black_and_White_Portrait_013.jpg')
rows,cols,ch = img.shape

pts1 = np.float32([[50,50],[200,50],[50,200]])
pts2 = np.float32([[10,100],[200,50],[100,250]])

M = cv2.getAffineTransform(pts1,pts2)

dst = cv2.warpAffine(img,M,(cols,rows))

plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()
print(img)
cv2.imshow('img',dst)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# [[[48 48 48]
#   [48 48 48]
#   [47 47 47]
#   ...
#   [65 65 65]
#   [65 65 65]
#   [65 65 65]]
#
#  [[48 48 48]
#   [48 48 48]
#   [47 47 47]
#   ...
#   [65 65 65]
#   [65 65 65]
#   [66 66 66]]
#
#  [[48 48 48]
#   [48 48 48]
#   [48 48 48]
#   ...
#   [66 66 66]
#   [66 66 66]
#   [66 66 66]]
#
#  ...
#
#  [[68 68 68]
#   [69 69 69]
#   [71 71 71]
#   ...
#   [38 38 38]
#   [38 38 38]
#   [38 38 38]]
#
#  [[64 64 64]
#   [66 66 66]
#   [68 68 68]
#   ...
#   [38 38 38]
#   [38 38 38]
#   [38 38 38]]
#
#  [[64 64 64]
#   [66 66 66]
#   [68 68 68]
#   ...
#   [38 38 38]
#   [38 38 38]
#   [38 38 38]]]
